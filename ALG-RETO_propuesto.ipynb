# %% [markdown]
# <img src="images/keepcoding.png" width=200 align="left">

# %% [markdown]
# # Módulo de Matemáticas 101: reto del fin de semana
#
# El reto de esta semana es implementar el algoritmo de Singular Value Decomposition para comprimir una imagen. Podéis guiaros por lo visto en las clases y os recomiendo también esta web:
#
# https://timbaumann.info/svd-image-compression-demo/

# %% [markdown]
# ## SVD para comprimir una imagen
#
# El algoritmo de Singular Value Decomposition, del que ya hemos hablado en el módulo, nos puede servir para comprimir una imagen. Vamos a implementar varias funciones para esto. Como repaso, el algoritmo nos devuelve la descomposición de una matriz en tres matrices, una de ellas con los elementos principales y las otras dos con los vectores principales.
#
# Usaremos:
#
# - Una imagen de `scipy.datasets`
# - La implementación del algoritmo en `scipy.linalg`: https://docs.scipy.org/doc/scipy-1.14.0/reference/generated/scipy.linalg.svd.html
# - La librería `matplotlib`para las gráficas
# - El error SSE (sum of squared estimate of errors)
#
#
# Definición:
#
# $$SSE =  \sum_{i=1}^{n}  (x_{i} -  \widehat{x}_i ) ^2 $$
#
# Donde:
#
# - $x_i$ son los valores de la matriz original X
# - $\widehat{x}_i$ son los valores de la matriz reconstruida $\widehat{X}$

# %% [markdown]
# Lo primero, vemos la imagen que vamos a comprimir:

# %%
# %pip install pooch
# %pip install --upgrade matplotlib

import matplotlib.pyplot as plt
from scipy import datasets
# %matplotlib inline

# Load image
A = datasets.face(gray=True)

plt.imshow(A, cmap=plt.cm.gray)
# Out:
# Requirement already satisfied: pooch in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch) (4.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch) (24.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
A
# Out:
# array([[114, 130, 145, ..., 119, 129, 137],
#        [ 83, 104, 123, ..., 118, 134, 146],
#        [ 68,  88, 109, ..., 119, 134, 145],
#        ...,
#        [ 98, 103, 116, ..., 144, 143, 143],
#        [ 94, 104, 120, ..., 143, 142, 142],
#        [ 94, 106, 119, ..., 142, 141, 140]], dtype=uint8)

# %%
type(A)
# Out:
# numpy.ndarray

# %% [markdown]
# Las siguientes funciones te ayudarán a llegar a la solución final:

# %% [markdown]
# ### 1. Implementa la función para el SEE (en clase)
# La función debe tener como entrada las dos matrices y como salida un número que será el error cometido.

# %%
import numpy as np

def sse_score(A, A_hat):
    #calcula el error cuadrático total, entre X(matriz original) y
    #X_hat(matriz estimada o aproximada)
    return np.sum((A - A_hat)**2) #Se suman todos los elementos del
                                  #resultado anterior para obtener el Error Cuadrático Total.


A = np.array([[1, 2], [3, 4]])
A_hat = np.array([[1.01, 1.75], [2.81, 3.99]])
sse = sse_score(A, A_hat)
print(sse)
# Out:
# 0.09879999999999997

# %% [markdown]
# ### 2. Implementa una función para ejecutar SVD
# La función debe tener como entrada una matriz y como salida las tres matrices de la descomposición.

# %%
import numpy as np
from scipy.linalg import svd

def svd(X):
    U, S, Vt = np.linalg.svd(X, full_matrices=False)
    S = np.diag(S)
    return U, S, Vt # es una matriz diagonal

A = np.array([[1, 2], [3, 4]])
U, S, Vt = svd(A_hat)
print(U)
print(S)
print(Vt)
# Out:
# [[-0.40455358 -0.9145143 ]
#  [-0.9145143   0.40455358]]
# [[5.46498572 0.        ]
#  [0.         0.        ]]
# [[-0.57604844 -0.81741556]
#  [-0.81741556  0.57604844]]

# %% [markdown]
# ### 3. Implementa una función para reconstruir la imagen
#
# Esta función deberá reconstruir la imagen a partir de un set de matrizes (U, S, Vt) dado.

# %%
def reconstruction(U, S, Vt):
    
    X_hat = np.dot(U,np.dot(S,Vt))
    return X_hat

U = np.array([[-0.40455358, -0.9145143 ],
              [-0.9145143 ,  0.40455358]])
S = np.array([[5.4649857 , 0.        ],
              [0.        , 0.36596619]])
Vt = np.array([[-0.57604844, -0.81741556],
               [ 0.81741556, -0.57604844]])
X_hat = reconstruction(U, S, Vt)
X_hat
# Out:
# array([5.43063126, 0.71291255])

# %% [markdown]
# En este punto, ya puedes ver cuál es el error cometido si se reconstruye la matriz inicial directamente después de aplicar SVD.

# %%
sse = sse_score(X, X_hat)
print(f"El error de reconstrucción es: {sse}")
# Out:
# El error de reconstrucción es: 0.13393125268149617

# %% [markdown]
# ### 4. Implementa la compresión
#
# Esta es la parte más complicada. A la función le tendremos que pasar la imagen, en forma matricial, y el número de componentes que queremos usar para la compresión.
#
# La función aplicará SVD y reconstruirá la matriz usando solo los n_comp primeros valores propios de la descomposición.

# %%
### TODO: Función que recibe una imagen A y devuelve la imagen comprimida
### Tiene como entrada A y el número de componentes para realizar la reducción de dimensionalidad
### Devuelve la imagen comprimidad y el error de reconstrucción

def image_compression(A, n_comp):
    # TODO 1: Aplicar SVD (usando la función que hemos creado)
    U, S, Vt = svd(A)

    # TODO 2: Reconstruir usando solo el número de componentes n_comp (usando la función que hemos creado)
    S_comp = np.diag(S[:n_comp])
    U_comp = U [:,:n_comp]
    Vt_comp = Vt[:n_comp, :]
    A_hat = reconstruction(U_comp, S_comp, Vt_comp)

    # TODO 3: Calcular el error
    sse = sse_score(A, A_hat)

    return A_hat, sse # A_hat es la matriz comprimida y sse es su error respecto de A

racoon = datasets.face(gray=True)
racoon_hat, sse = image_compression(racoon, n_comp=50)

# %% [markdown]
# ### 5. Gráficas del resultado
#
# Por último, se pide que pruebes para varios valores del número de componentes y grafiques la imagen original junto con varias compresiones. Puedes usar un grid 2x2 de `matplotlib`.

# %%
# %pip install --upgrade matplotlib
     
import matplotlib.pyplot as plt
# TODO Dibuja las graficas`
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(racoon, cmap=plt.cm.gray)

# 1 Crear gráfica con plt.figure()
plt.subplot(1, 2, 2)
plt.imshow(racoon_hat, cmap=plt.cm.gray)

# 2 Elegir un n_comp y aplicar la función image_compression() 
n_comp = 50
racoon_hat, _ = image_compression(racoon, n_comp)

# 3 Usar plt.imshow(A_hat, cmap=plt.cm.gray), donde A_hat va a ser la matriz comprimida resultante del paso anterior
plt.imshow(racoon_hat, cmap=plt.cm.gray)
# 4 Añadir un título a la gráfica
plt.title("Error de reconstrucción: %.2f" % sse)
plt.show()
# Repetir para distintas compresiones (distinto n_comp)
# Out:
# Requirement already satisfied: matplotlib in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pauci\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,2, figsize= (16, 12))
axes = axes.ravel()
axes[0].imshow(A, cmap=plt.cm.gray)
axes[0].set_title("Imagen sin comprimir")
componentes = [10, 25, 50]
for plot, comp in zip(range(1,4), componentes):
    racoon_hat, _ = image_compression(racoon, n_comp=comp)
    axes[plot].imshow(racoon_hat, cmap=plt.cm.gray)
    axes[plot].set_title(f"Imagen con {comp} valores principales")
